# %%
import pandas as pd
import json

# %%
#with open('stock_list_s2006e2021.json', 'r', encoding='utf-8') as fh:
#    sd = json.load(fh)

# %%
sdf = pd.read_csv('stock_list.csv')
sdf
# Out:
# C:\Users\terwu01\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         id     name  s2006e2007bao  s2006e2007bah  s2006e2007bal  \
# 0     0050   元大台灣50           15.6           14.7           15.9
# 1     0051  元大中型100           12.7           11.5           13.0
# 2     0052     富邦科技            9.0            8.2            9.4
# 3     0053     元大電子          -10.8          -11.0           -9.5
# 4     0054   元大台商50           -4.1           -4.8           -3.1
# ...    ...      ...            ...            ...            ...
# 2617  9982      NaN            NaN            NaN            NaN
# 2618  9983      NaN            NaN            NaN            NaN
# 2619  9984      NaN            NaN            NaN            NaN
# 2620  9985      NaN            NaN            NaN            NaN
# ...

# %%
exp_df = pd.DataFrame(sdf['s2006e2007_bao'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 's2006e2007_bao'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d101fd262558> in <module>
# ...
